# %%
from jupyterthemes import jtplot
jtplot.style(theme='oceans16',context='talk', fscale=1.4, spines=True, gridlines='--',ticks=True, grid=True)
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':(8,4)}); np.random.seed(0)

# %%
## 5. 数值分布图
# 绘制数值变量的密度分布图
# 默认既绘制核密度曲线，也绘制直方图
x = np.random.randn(100)
ax = sns.distplot(x)

# %%
# 只绘制核密度曲线，不绘制直方图
ax = sns.distplot(x, rug=True, hist=False)

# %%
# 把图横着放
ax = sns.distplot(x, vertical=True)

# %%
#绘制核密度图
import numpy as np
import seaborn as sns
np.random.seed(10)
sns.set(color_codes=True)

# %%
mean, cov = [0,2],[(1,.5), (.5, 1)]
x, y = np.random.multivariate_normal(mean,cov,size=50).T
print(x,y)
# Out:
# [ 0.85199154  0.56438715  0.32509446 -0.16777477 -0.21849867 -0.01829048
#  -1.71252868  0.44535861  0.30965579  0.57281773  1.1565545  -2.30324776
#  -1.37103081 -0.96893006 -1.76870349  0.76391523  0.39730861  1.17250167
#  -1.17506508 -2.44297729  0.92874967  0.28199868 -1.13434776  1.1670006
#  -0.85531009 -0.64944047 -1.41117162  0.17660907  0.33900942  0.67356909
#  -1.02668749 -0.73032811  2.58558244  0.68416945  0.02001437  1.17568247
#  -1.23491625  0.74773216 -0.77655216 -0.72475432  1.56999201 -0.83434501
#  -1.98554022 -0.12319298 -0.03951552 -0.20248085  0.99658028 -0.28898636
#  -0.3090799  -0.72480905] [ 0.94453465  3.03413859  1.92495611  2.68043384  0.99423241  1.51090226
#  -0.45188542  2.09647669  2.45075996  0.95424698  1.83610696  2.16207732
#   0.97520231  1.19788021  0.89918612  1.63436404  2.71113913  2.95070853
#   0.85424463  1.00418831  1.56943909  1.80121134  2.48006022  2.77827265
#   2.27966309  1.76485717  1.0823437   2.23389422  2.88567425 -0.30602768
# ...

# %%
ax = sns.kdeplot(x)

# %%
# shade参数决定是否填充曲线下面积
ax = sns.kdeplot(x, shade=True, color='r')

# %%
# 双变量密度图，相当于等高线图了
# shade参数改用颜色深浅表示密度的大小，如果不用就真的是等高线图了
ax = sns.kdeplot(x, y, shade=True)

# %%
# 分组绘制双变量的核密度图
# 相当于绘制两个核密度图，通过图可以看到密度中心
# 类似于挖掘算法中聚类中心绘图
iris = sns.load_dataset('iris')
setosa = iris.loc[iris.species=='setosa'] #组1
virginica = iris.loc[iris.species=='virginica'] #组2

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                cmap='Reds', shade=True,shade_lowest=False)

# %%
ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                cmap='Blues', shade=True, shade_lowest=False)

# %%
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                cmap='Reds', shade=True,shade_lowest=False)
ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                cmap='Blues', shade=True, shade_lowest=False)

# %%
# 双变量关系图jointplot - draw a plot of two variables with bivariate and univariate graphs
# kind参数可以使用不同的图形反映两变量的关系，比如点图，线图，核密度图
tips = sns.load_dataset('tips')
g = sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
# 通过kind参数，除了绘制散点图，还要绘制拟合的直线，拟合的核密度图
g = sns.jointplot('total_bill', 'tip', data=tips, kind='reg')

# %%
# 使用六角形代替点图
g = sns.jointplot('total_bill', 'tip', data=tips,kind='hex')

# %%
# 绘制核密度图
iris = sns.load_dataset('iris')
g = sns.jointplot('sepal_width', 'petal_length', data=iris,
                 kind = 'kde', space=0, color='g')

# %%
# 控制图形的大小和颜色
g = sns.jointplot('total_bill', 'tip', data=tips,
                 size=5, ratio=3,color='g')

# %%
# x-y的散点图，不画回归线， fit_reg=False
tips = sns.load_dataset('tips')
g = sns.lmplot(x='total_bill', y='tip', data=tips,
              fit_reg=False,hue='smoker', scatter=True)

# %%
# 只画回归线，不画散点图，scatter = False
g = sns.lmplot(x='total_bill', y='tip', data=tips,
              fit_reg=True, hue = 'smoker', scatter=False)

# %%
# 画变量关系组图
g = sns.pairplot(iris)

# %%
g = sns.pairplot(iris, hue='species')

# %%
# hue分组后，不同的组用不同的形状标记
g = sns.pairplot(iris,hue='species', markers=['o', 's', 'D'])

# %%
# 当然也可以只取dataframe中的一部分变量绘图
g = sns.pairplot(iris,vars=['sepal_width', 'sepal_length'])

# %%
# 对角线默认绘制直方图，当然也可以绘制核密度图
g = sns.pairplot(iris,diag_kind='kde')

# %%
## 6.热力图
# 6.1 热力图heatmap
import pandas as pd
np.random.seed(0)
sns.set()
uniform_data = np.random.rand(10,12)
ax = sns.heatmap(uniform_data)

# %%
# 改变颜色映射的值范围
ax = sns.heatmap(uniform_data, vmin=0, vmax=1, cmap='RdBu')

# %%
# 绘制x-y-z的热力图，比如年-月销量的热力图
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot('month', 'year', 'passengers')
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
ax = sns.heatmap(flights)

# %%
#绘制热力图时，还要将数值写到热力图上
ax = sns.heatmap(flights, annot=True, fmt='d')

# %%
# 这个图在绘制缺失值分布有用
# plot every other column label and don't plot row labels
data = np.random.randn(50, 20)
ax = sns.heatmap(data, xticklabels=2, yticklabels=False)

# %%
# 时间序列图
# 直接传入一个list或者是series, 直接绘制线图
# plot a trace with transplucent confidence bands:
# 绘制带有半透明置信带的轨迹
np.random.seed(22)
sns.set(color_codes=True)
x = np.linspace(0,15,31)
data = np.sin(x) + np.random.rand(10,31) + np.random.randn(10,1)
g = sns.tsplot(data=data)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
gammas = sns.load_dataset('gammas')
ax = sns.tsplot(time='timepoint', value='BOLD signal',
               unit='subject', condition='ROI', data=gammas)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
# 绘制不同的置信度拟合图
ax = sns.tsplot(data=data, ci=[68,95], color='m')
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
# 使用不同的统计函数，默认的是均值，这里是中位数
ax = sns.tsplot(data=data,estimator=np.median)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
# 8.2 Panda 线图 - pandas本身也有绘图函数，而且可以在plot函数中指定title
gammas.loc[(gammas['ROI']=='IPS') & (gammas['subject'] == 1)].plot(x='timepoint', y='BOLD signal')

# %%
time_point = gammas['timepoint']
bold_signal = gammas['BOLD signal']

# %%
# 8.3 采样的时序图
def plot_ts_day(x,y):
    """绘制每天的时间序列图
    需要注意的是，序列是不是连续的
    x: 时间轴，string或者time类型，是一个seires
    y: 值
    """
    # x转成时间类型Timestamp, y也转成list
    x = [pd.to_datetime(str(i)) for i in x]
    y = [i for i in y]
    s = pd.Series(y, index=x)
    s = s.resample(rule='D', fill_method='ffill') # 生采样没有的会被填充
    # 原来没有的就填充为0
    s[s.index]=0
    s[x] = y
    # 原来没有的就填充为0
    x2 = [i.strftime('%Y-%m-%d') for i in s.index]
    s.index = x2
    # 画图，这里使用series的plot函数，而不是seaborn.tsplot函数
    s.plot()

# %%
def plot_ts_month(x,y):
    """绘制月的时间序列图，每月一个数据点，而不是每天一个"""
    # 将x转成时间类型timestamp,y也转成list
    try:
        x = [pd.to_datetime(str(i)) for i in x]
    except:
        x = [pd.to_datetime(str(i) + '01') for i in x]
    y = [i for i in y]
    s = pd.Series(y, index=x)
    # 降采样至月
    s = s.resample('M', label='right').sum().fillna(0)
    # 重建索引，这样画出来的图好看点
    s.index=[i.strftime('%Y%m') for i in s.index]
    s.plot()

# %%
# 双坐标抽图
import seaborn as sns
sale = pd.Series(np.random.randn(10)*100).map(int)
temperature = pd.Series(np.random.random(10)*100).map(int)

# %%
from matplotlib import pyplot as plt
ax = plt.subplot(111)
sale.plot(ax=ax, color='b')
ax.set_xlabel('time')
ax.set_ylabel('sale')
ax2 = ax.twinx()
temperature.plot(ax=ax2, color='r')
ax2.set_ylabel('temperature')
plt.title('double series figure')
# Out:
# Text(0.5,1,'double series figure')

# %%
# 分段统计绘图
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
data = pd.cut(ages,bins = [18,30,50,80,100],right = True,precision =1)
cnt = data.value_counts()
sns.barplot(x=data, y=cnt,data=ages, estimator=np.sum, ci=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-3ae3e4f986cd> in <module>()
#       3 data = pd.cut(ages,bins = [18,30,50,80,100],right = True,precision =1)
#       4 cnt = data.value_counts()
# ----> 5 sns.barplot(x=data, y=cnt,data=ages, estimator=np.sum, ci=0)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    2957                           estimator, ci, n_boot, units,
#    2958                           orient, color, palette, saturation,
# -> 2959                           errcolor, errwidth, capsize, dodge)
#    2960
#    2961     if ax is None:
#
# ...

# %%
# 因子变量绘图
# 3.1 boxplot箱线图
import seaborn as sns
sns.set_style('whitegrid')
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.boxplot(x=tips['total_bill'])

# %%
# 竖着放的
ax = sns.boxplot(y=tips['total_bill'])

# %%
ax = sns.boxplot(x='day', y='total_bill', data=tips)

# %%
g = sns.boxplot(x='sex', y='tip', hue='smoker', data=tips)

# %%
# 分组箱线图，分子因子是smoker，不同的因子用不同颜色区分
# 相当于分组之后又分组
ax = sns.boxplot(x='day', y='total_bill', hue='smoker',
                data=tips, palette='Set3')

# %%
# 改变线宽，linewidth参数
ax = sns.boxplot(x='day', y='total_bill', hue='time',
                data=tips, linewidth=2.5)

# %%
# 改变x轴顺序，order参数
g = sns.boxplot(x='time', y='tip', data=tips,
               order=['Dinner', 'Lunch'])

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 对dataframe的每个变量都绘制一个箱线图，水平放置
g = sns.boxplot(data=iris, orient='h', palette='Set2')

# %%
# 箱线图+有分布趋势的散点图
# 图形组合也就是两条绘图语句一起运行就可以了，相当于图形覆盖了
g = sns.boxplot(x='day', y='total_bill', data=tips)
g = sns.swarmplot(x='day', y='total_bill', data=tips, color='.25')

# %%
### violinplot小提琴图
# 小提琴图其实是箱线图与核密度图的结合，箱线图展示了分位数的位置，小提琴图则展示了任意位置的密度，通过小提琴图可以知道哪些位置的密度较高。在图中，白点是中位数，黑色盒型的范围是下四分位点到上四分位点，细黑线表示须。外部形状即为核密度估计（在概率论中用来估计未知的密度函数，属于非参数检验方法之一）。
g = sns.violinplot(x='total_bill', data=tips)
g = sns.violinplot(x=tips['total_bill'])

# %%
# 分组的小提琴图，同上面的箱线图一样通过X轴分组
g = sns.violinplot(x='day', y='total_bill', data=tips)

# %%
g = sns.violinplot(x=tips['day'], y=tips['tip'])

# %%
# 通过hue分组的小提琴图，相当于分组之后又分组
g = sns.violinplot(x='day', y='total_bill', hue='sex',
                  data=tips, palette='muted')

# %%
# 分组组合的小提琴图，其实就是hue分组后，各取一半组成一个小提琴图
g = sns.violinplot(x='day', y='total_bill', hue='smoker',
                  data=tips, palette='muted', split=True)

# %%
# 调整x轴顺序，同样通过order参数
g = sns.violinplot(x='time', y='tip',
                  data=tips, order=['Dinner', 'Lunch'])

# %%
# stripplot 散点图
# 普通的散点图
ax1 = sns.stripplot(x=tips['total_bill'])

# %%
# 带分布密度的散点图
ax2 = sns.swarmplot(x=tips['total_bill'])

# %%
# 分组的散点图
# 添加抖动项的散点图，jitter可以是0.1,0.2...这样的小数，表示抖动的程度大小ax = sns.stripplot(x='day', y='total_bill', data=tips)

# %%
# 添加抖动项的散点图，jitter可以是0.1,0.2...这样的小数，表示抖动的程度大小
g = sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)

# %%
# change the direction
g = sns.stripplot(x='tip', y='day', data=tips, jitter=True)

# %%
# 重点来了，分组绘制，而且是分组后分开绘制，在柱状图中，跟分组柱状图类似的。
# 通过 hue, split 参数控制
# 1.分组
g = sns.stripplot(x='sex', y='total_bill', hue='day',
                 data=tips, jitter=True)

# %%
g = sns.stripplot(x='day', y='tip', hue='sex',
                 data=tips, jitter=True, split=True)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
# 2.分开绘制
g = sns.stripplot(x='day', y='total_bill', hue='smoker',
                 data=tips, jitter=True, palette='Set2', split=True)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2586: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
# 散点图+小提起图
# 两条命令一起运行就行了
g = sns.violinplot(x='day', y='total_bill', data=tips,
                  inner=None, color='.8')
g = sns.stripplot(x='day', y='total_bill', data=tips, jitter=True)

# %%
# 3.4.swarmplot带分布的散点图
g = sns.swarmplot(x=tips['total_bill'])

# %%
# 分组的散点图
g = sns.swarmplot(x='day', y='total_bill', data=tips)

# %%
# 箱线图+散点图
# whis 参数设定是否显示箱线图的离群点，whis=np.inf 表示不显示
g = sns.boxplot(x='tip', y='day', data=tips, whis=np.inf)
g = sns.swarmplot(x='tip', y='day', data=tips)

# %%
g = sns.boxplot(x='day', y='total_bill', data=tips, hue='sex', whis=np.inf)
g = sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex', split=True)
# Out:
# /Users/gaoziyao/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2783: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
# 小提琴图+散点图
g = sns.violinplot(x='day', y='total_bill', data=tips, inner=None)
g = sns.swarmplot(x='day', y='total_bill', data=tips,
                 color='white', edgecolor='gray')

# %%
# 3.5.pointplot
# Show point estimates and confidence intervals using scatter plot glyphs.

# %%
### 3.6.barplot直方图
g = sns.barplot(x='day', y='total_bill', data=tips)

# %%
# 不显示直方图上面的置信度线，难看，所以下面的图形我都设置ci=0.
g = sns.barplot(x='day', y='tip', data=tips, ci=0)

# %%
# 分组的柱状图
g = sns.barplot(x='day', y='tip', data=tips, hue='sex', ci=0)

# %%
# 绘制变量中位数的直方图，estimator指定统计函数
from numpy import median
g = sns.barplot(x='day', y='tip', data=tips,
               estimator=median, ci=0)

# %%
from numpy import mean
g = sns.barplot(x='day', y='tip', data=tips,
               estimator=mean, ci=0)

# %%
from numpy import sum
g = sns.barplot(x='day', y='total_bill', 
               data = tips, estimator=sum, ci=0)

# %%
# 改变主题颜色
# palette="Blues_d"
g = sns.barplot(x='day', y='total_bill', data=tips, estimator=median,
               palette='Blues_d', ci=0)

# %%
# 3.7.countplot计数统计图
g = sns.countplot(x='species', data=iris)

# %%
# 分组绘图
g = sns.countplot(x='day', hue='sex', data=tips)

# %%
# 如果是横着放，x用y替代
g = sns.countplot(y='day', hue='sex', data=tips)

# %%
# 3.8.factorplot
# 用小提琴图 反应 time-pulse 两变量的分布情形
g = sns.factorplot(x='day', y='tip', hue='sex', data=tips,
                  kind='violin')

# %%
# 不同的deck（因子）绘制不同的alive（数值），col为分子图绘制，col_wrap每行画4个子图
g = sns.factorplot(x='day', col='sex', col_wrap=4,
                  data=tips,
                   kind='count', size=2.5, aspect=.8)

# %%
# 回归图
# lmplot： Plot data and regression model fits across a FacetGrid. 
# regplot：Plot data and a linear regression model fit.
g = sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
# 分组的线性回归图，通过hue参数控制
g = sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips)

# %%
# 分组绘图，不同的组用不同的形状标记
g = sns.lmplot(x='total_bill', y='tip', hue='smoker',
              data=tips, markers=['o', 'x'])

# %%
# 不仅分组，还分开不同的子图绘制，用col参数控制
g = sns.lmplot(x='total_bill', y='tip', col='smoker', hue='smoker',data=tips)

# %%
# col+hue 双分组参数，既分组，又分子图绘制，jitter控制散点抖动程度
g = sns.lmplot(x='size', y='total_bill', hue='day',
              col='day', data=tips, aspect=.4, x_jitter=.1)

# %%
# 分组绘制，控制size尺寸
g = sns.lmplot(x='total_bill', y='tip', col='day',
              hue='day', data=tips, col_wrap=2, size=3)

# %%
sns.pairplot(tips)

# %%
# 既然col可以控制分组子图的，那么row也是可以控制分组子图的
g = sns.lmplot(x='total_bill', y='tip', row='sex',
              col='time', data=tips, size=3)

# %%
g = sns.lmplot(x='total_bill', y='tip', row='smoker',
              col='sex', data=tips, size=3)

# %%
# 4.2.回归图regplot
g = sns.regplot(x='total_bill', y='tip', data=tips)

# %%
# 控制散点的形状和颜色
import numpy as np; np.random.seed(8)
mean, cov = [4, 6], [(1.5, 0.7), (.7, 1)]
x, y=np.random.multivariate_normal(mean, cov, 80).T
print(x, y)
# Out:
# [3.44726746 6.81539447 5.66215268 1.10199747 2.6823407  4.57995181
#  5.56867551 4.76124869 3.10266131 4.16132751 2.69450729 4.02721271
#  6.09785089 2.90386409 4.08930058 2.42605325 3.88931944 4.29469192
#  3.92991213 4.74561006 5.04364401 3.8031927  3.95375021 1.62320471
#  7.15063408 6.88738557 4.40653348 1.92083529 5.61028658 3.11610987
#  3.11943056 3.0566188  4.19824251 5.03461271 1.20678398 3.32099525
#  3.78516436 3.97689828 2.09250164 4.32356516 3.97899144 3.82440539
#  3.45967688 3.66860023 4.3762474  3.97336676 6.70686665 0.59122173
#  2.88306768 4.30065454 2.88854874 4.27562126 3.64390126 5.78560841
#  1.41399578 5.95802375 2.20755534 4.1574671  4.93507683 5.2295702
#  6.29102716 1.96006909 4.02779938 4.92678105 5.22293934 5.08695352
#  5.27183408 5.29554524 3.85162622 4.302678   3.47879485 1.97402308
#  4.65957301 5.26505996 4.87690061 3.90390506 4.82104964 4.97855378
#  5.0683593  4.18817473] [6.56079547 6.77679417 9.26989578 5.87750555 5.92171247 8.07752124
# ...

# %%
ax = sns.regplot(x=x, y=y, color='g', marker='+')

# %%
g = sns.regplot(x='tip', y='total_bill', marker='+', data=tips)

# %%
# 控制回归的置信度，你会看到拟合直线的外面的面积的有变化的
g = sns.regplot(x=x, y=y, ci=68)

# %%
# 上面的都是拟合一次曲线，拟合二次曲线通过order=2设置，
# 拟合一次曲线相当于 order=1
g = sns.regplot(x='total_bill', y='tip', data=tips.loc[tips['size']== 2],
               scatter_kws={'s':80}, order=2, ci=None, truncate=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
